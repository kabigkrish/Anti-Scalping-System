# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.7/dist-packages (0.3.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from pytesseract) (7.1.2)

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
filename = 'TARP1.jfif'
img1 = np.array(Image.open(filename))
cv2_imshow(img1) #cv2.imshow('name',file) python
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# <PIL.Image.Image image mode=RGB size=227x180 at 0x7FDAEA928C10>
# Tight

# %%
filename = 'TARP2.jfif'
img1 = np.array(Image.open(filename))
cv2_imshow(img1)
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# <PIL.Image.Image image mode=RGB size=317x153 at 0x7FDAEA9AED90>
# G
#
# hesseract OC

# %%
filename = 'TARP3.jfif'
img1 = np.array(Image.open(filename))
cv2_imshow(img1)
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# <PIL.Image.Image image mode=RGB size=240x100 at 0x7FDAEA93CD50>
# A Python Approach
# Recognition

# %%
filename = 'test1.jpg'
img1 = np.array(Image.open(filename))
cv2_imshow(img1)
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# <PIL.Image.Image image mode=RGB size=459x612 at 0x7FDAEA94D510>
#
#
#
#
#
# (ir Reed |

# %%
filename = 'test2.jpg'
img1 = np.array(Image.open(filename))
cv2_imshow(img1)
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# <PIL.Image.Image image mode=RGB size=430x573 at 0x7FDAEA956050>
#
#
#
#
# QdaN z
# INZME Beat ye =
# 3

# %%
filename = 'test3.jpg'
img1 = np.array(Image.open(filename))
cv2_imshow(img1)
text = pytesseract.image_to_string(img1)
print(text)
# Out:
# <PIL.Image.Image image mode=RGB size=430x573 at 0x7FDAF3BB9650>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wl
#
# AWB 181836776505
#
#
#
#
#
#
#
#
#
# tt
#
# pita aa
# or, sive; Cty ~2 Sector
#
# fe =e neon 201810
#
# UTTAR PRA
#
# tant Gree Noite
#
# NDL: sliver aly 201810,
#
#
#
# TARG!
#
# asa
#
# 27/02)
#
#
#
#
#
#
#
#
#
#
#
#
#
# (= VOEL |NZMF
#
# 22
#
# ‘S6ld or www tieron a

# %% [markdown]
# ### **NEW TRY**

# %%
import cv2 
import pytesseract

img = cv2.imread('TARP1.jfif')

# Adding custom options
custom_config = r'--oem 3 --psm 6'
cv2_imshow(img)
pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=227x180 at 0x7FDAF423BA90>
# 'Tonight\n\x0c'

# %%
import cv2 
import pytesseract

img = cv2.imread('TARP2.jfif')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=317x153 at 0x7FDAEA8DC2D0>
# 'hesseract OC\n\x0c'

# %%
import cv2 
import pytesseract

img = cv2.imread('TARP3.jfif')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=240x100 at 0x7FDAEA8DC9D0>
# 'A Python Approach\nRecognition\n\x0c'

# %%
import cv2 
import pytesseract

img = cv2.imread('test1.jpg')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=459x612 at 0x7FDAEA94DC50>
# 'f yS\nfa ™ 2\nWWM\nPare\n~ supre, tmmrernesrer— | orine_| i\neaters .\nm= 4 fa pate\nte Ae: Le :\n| SRR er CH a, tn -_\na\n5 el ,\n6 ! arse\nyomUN alee —\n\x0c'

# %%
import cv2 
import pytesseract

img = cv2.imread('test2.jpg')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=430x573 at 0x7FDAEA93CFD0>
# 'QdN z\n[sua]\n\npms\n\nEEE\n\x0c'

# %%
import cv2 
import pytesseract

img = cv2.imread('test3.jpg')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=430x573 at 0x7FDAEA8EB610>
# 'j 4 | f\n\na |\n\noS ke\n\nLARGE Sa Fe\nsnpre_ $48 1810677058 zine, | bs\n\nPic? QREATER NOIDA 201819 PREPAID | } E\nGrran PRADEEH — ea\ntavanere era Nola Towa) E° ae\nDn ey 20910 ea % <= be\n“ res, |! 1\nStead Deed fe beet\napse gard Beet (es E\nGES) Pied Bete IRR! |\nSe\n(a Senter “| cstin TWVOIGE —[OATE [TEM Ty!\nfe ee ee\nsae “i\nF) | VOEL iS\ny 22 pe\nold on www amazon ATSP| foe\n\x0c'

# %% [markdown]
# **# With Preprocessing**

# %%
import cv2
import numpy as np

image = cv2.imread('TARP1.jfif')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 


gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
custom_config = r'--oem 3 --psm 6'
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
print(pytesseract.image_to_string(image, config=custom_config))
print(pytesseract.image_to_string(gray, config=custom_config))
print(pytesseract.image_to_string(opening, config=custom_config))
print(pytesseract.image_to_string(canny, config=custom_config))
# Out:
# <PIL.Image.Image image mode=L size=227x180 at 0x7FDAEA8EE750>
# <PIL.Image.Image image mode=L size=227x180 at 0x7FDAEA8E0410>
# <PIL.Image.Image image mode=L size=227x180 at 0x7FDAEA8E0B10>
# Tonight
#
# . a
#
# Tonight
#
# Ronin
# ge)

# %%
import cv2
import numpy as np

image = cv2.imread('TARP2.jfif')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 


gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
custom_config = r'--oem 3 --psm 6'
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
print(pytesseract.image_to_string(image, config=custom_config))
print(pytesseract.image_to_string(gray, config=custom_config))
print(pytesseract.image_to_string(opening, config=custom_config))
print(pytesseract.image_to_string(canny, config=custom_config))
# Out:
# <PIL.Image.Image image mode=L size=317x153 at 0x7FDAEA8EE790>
# <PIL.Image.Image image mode=L size=317x153 at 0x7FDAEA8E0F90>
# <PIL.Image.Image image mode=L size=317x153 at 0x7FDAEA8EE890>
# hesseract OC
#
# Tesseract OC
#
# fe
# wd
# Tesseract OC
#
# Tesseract OC

# %%
import cv2
import numpy as np

image = cv2.imread('TARP3.jfif')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 


gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
custom_config = r'--oem 3 --psm 6'
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
print(pytesseract.image_to_string(image, config=custom_config))
print(pytesseract.image_to_string(gray, config=custom_config))
print(pytesseract.image_to_string(opening, config=custom_config))
print(pytesseract.image_to_string(canny, config=custom_config))
# Out:
# <PIL.Image.Image image mode=L size=240x100 at 0x7FDAEA905410>
# <PIL.Image.Image image mode=L size=240x100 at 0x7FDAEA905350>
# <PIL.Image.Image image mode=L size=240x100 at 0x7FDAEA905410>
# A Python Approach
# Recognition
#
# A Python Approach
# Recognition
#
# A Python Approeah
# Recognition
#
# A Python Approach
# Recognition

# %%
import cv2
import numpy as np

image = cv2.imread('test1.jpg')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 


gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
custom_config = r'--oem 3 --psm 6'
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
print(pytesseract.image_to_string(image, config=custom_config))
print('GRAY')
print(pytesseract.image_to_string(gray, config=custom_config))
print('OPENING')
print(pytesseract.image_to_string(opening, config=custom_config))
print('CANNY')
print(pytesseract.image_to_string(canny, config=custom_config))
# Out:
# <PIL.Image.Image image mode=L size=459x612 at 0x7FDAEA90F950>
# <PIL.Image.Image image mode=L size=459x612 at 0x7FDAF7CA1B90>
# <PIL.Image.Image image mode=L size=459x612 at 0x7FDAEA90F990>
# f yS
# fa ™ 2
# WWM
# Pare
# ~ supre, tmmrernesrer— | orine_| i
# eaters .
# m= 4 fa pate
# te Ae: Le :
# | SRR er CH a, tn -_
# a
# 5 el ,
# 6 ! arse
# yomUN alee —
#
# GRAY
# 6 a ~~
# Lae
# +MY
# ante, Averseesorer 72 i
# Pram suhurmae,
#
# Rees : :
#
# fa = rN
#
# | eer a .
# | [ize Red
# \ te = ‘d rs
# | 2 ef Berit
# | SRR er AE a, etn v4
#
# I occaenk
#
# : x
# , = = ca
# DELX >
# ae a
# —— | samen By
# = arse
# ' 1% = a
# yonun ‘pasnuliedjsy) i
#
# OPENING
# La 2 .
# — [a
# Ba aa
# ama
# ? =
# ; a
#
# CANNY
# 35 i
# a:
# A |
# 7 IN | —
# \ Po aie aa
# a
# eo ek
# i pated 5
# nace arty
# panes SR mec
# oe
# ; Ee cceramem
# D a TT
# a
# 2 7
# ora ae .
# az sf
# a aaa

# %%
import cv2
import numpy as np

image = cv2.imread('test2.jpg')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 


gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
custom_config = r'--oem 3 --psm 6'
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
print(pytesseract.image_to_string(image, config=custom_config))
print('GRAY')
print(pytesseract.image_to_string(gray, config=custom_config))
print('OPENING')
print(pytesseract.image_to_string(opening, config=custom_config))
print('CANNY')
print(pytesseract.image_to_string(canny, config=custom_config))
# Out:
# <PIL.Image.Image image mode=L size=430x573 at 0x7FDAEA94D7D0>
# <PIL.Image.Image image mode=L size=430x573 at 0x7FDAEA93C750>
# <PIL.Image.Image image mode=L size=430x573 at 0x7FDAF423BD90>
# QdN z
# [sua]
#
# pms
#
# EEE
#
# GRAY
# ae 4
# MM Ks
# = Se
# ae te
#
# OPENING
# 9oN = 3
# maf
# pT
# Se
# | =
# -———————
#
# CANNY
# QaN a
# _ 80m 7
# eR a
# oe es
# ee E
# (aa
# st a RSE
# es

# %%
import cv2
import numpy as np

image = cv2.imread('test3.jpg')

# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED) 


gray = get_grayscale(image)
thresh = thresholding(gray)
opening = opening(gray)
canny = canny(gray)
custom_config = r'--oem 3 --psm 6'
cv2_imshow(gray)
cv2_imshow(opening)
cv2_imshow(canny)
print(pytesseract.image_to_string(image, config=custom_config))
print('GRAY')
print(pytesseract.image_to_string(gray, config=custom_config))
print('OPENING')
print(pytesseract.image_to_string(opening, config=custom_config))
print('CANNY')
print(pytesseract.image_to_string(canny, config=custom_config))
# Out:
# <PIL.Image.Image image mode=L size=430x573 at 0x7FDAEA8DCD90>
# <PIL.Image.Image image mode=L size=430x573 at 0x7FDAEA905110>
# <PIL.Image.Image image mode=L size=430x573 at 0x7FDAEA905110>
# j 4 | f
#
# a |
#
# oS ke
#
# LARGE Sa Fe
# snpre_ $48 1810677058 zine, | bs
#
# Pic? QREATER NOIDA 201819 PREPAID | } E
# Grran PRADEEH — ea
# tavanere era Nola Towa) E° ae
# Dn ey 20910 ea % <= be
# “ res, |! 1
# Stead Deed fe beet
# apse gard Beet (es E
# GES) Pied Bete IRR! |
# Se
# (a Senter “| cstin TWVOIGE —[OATE [TEM Ty!
# fe ee ee
# sae “i
# F) | VOEL iS
# y 22 pe
# old on www amazon ATSP| foe
#
# GRAY
# l iv x
# HUI EE
# zoe tus Pee
# ae 2s
# snipto; WB 136770808 202. | pS
# Pritam Sethurtman a Es
# A inaiast a mgr | iP
# Brians J bs
# pee peel
# Feat sos Fg
# Eas ta
# faa) ited Bae! eee
# Pee ST Se pans Sverre ea osu Gobi acts
# (SELLER Geri TNVOIG¢E [DATE [ive tye
# RT arssonricy jee Toate =) eee | i 00 i
# a : [ee es. | —
# s ;
# At j
# | DEE | WDEL
# 22!
# Setter weretinecon ATSPI
#
# OPENING
# ul 2: F
# aa:
# oO Be
#
# CANNY
# a Ha i [ses
# | exci a
# I no
# oe aaa cE
# Fano o a ni a
# Peon es [rarer eee
# eee — 7 mae
# i a
# rae ea
# i SC ca 2
# eae mE Bea gees
# eee ee
# ; al Ex cae ae age | >
# Be ae,
# rere et a
# A 2 cacao a ero :
# i SS
# ; eS Cae Tea
# peas za
# a Eyes | -
# aman . ;
# aed al coal j
# i fed :
# ese _ Pai

# %% [markdown]
# ###Pdf to Jpg

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 3.0MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61085 sha256=f473854a23d7577c4071c489bac5a643a820404cf4d09d2af3c8e7b2fe5c3b95
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %%
# importing required modules
import PyPDF2

# creating a pdf file object
pdfFileObj = open('invoice1.pdf', 'rb')

# %%
# creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
# printing number of pages in pdf file
print(pdfReader.numPages)
# Out:
# 1

# %%
# creating a page object
pageObj = pdfReader.getPage(0)

# %%
# extracting text from page
print(pageObj.extractText())

# %%
# closing the pdf file object
pdfFileObj.close()

# %% [markdown]
# ### Regex and Tesseract With E-Copy

# %%
import cv2 
import pytesseract

img = cv2.imread('invoice1.PNG')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
extract=pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=1481x800 at 0x7FDAE9876A50>

# %%
extract
# Out:
# 'Tax Invoice Order Id: OD119306027932627000 _Invoice No: FACDS42100004180 GSTIN: 07BKJPG6024L1Z1\nOrder Date: 31-07-2020, 07:47 PM Invoice Date: 31-07-2020, 07:48 PM PAN: BKJPG6024L\nSold By Shipping ADDRESS Billing Address\n‘Supplies World, Pritam , Pritam B1/311, Tower-9, Silver City-2,\nD-14,U.G.F,D.D.A-LS.C,Plot No. 2,4&20-Mor Land, B1/311, Tower-9, Silver City-2, Pi2,\nNew Rajinder Nagar, New Delhi, Pi-2, Opposite to Wipro Office,\nDELHI - 110060 Opposite to Wipro Office, Greater Noida - 201308, IN-UP\nGreater Noida - 201308, IN-UP\nGross Taxable\nProduct Description Qty Amount Discount“ Yotue IGsT Total\nPhilips SHE4305BK/00 Wired Headset Black | . . 7\nPhiipe SHE430SBK/00 Headset w HSN: 85183000 | IGST: 18% 1 589.00 0.00 499.15 89.85 589.00\nShipping Charge 1 0.00 0 0.00 0.00 0.00\nTOTAL PRICE: 589.00\nTOTAL QTY: 1 All values are in INR\nSeller Registered Address: Supplies World,\nD-14, UGF, DDALSC, , 2,4,20 Mor Land, New Rajinder Nagar, NEW DELHI - 110060.\nDeclaration\nThe goods sold are intended for end user consumption and not for resale.\nE&OE Ordered Through\nFlipkart (74 suppl\nupplies World\nRuthePecd Signature\n\x0c'

# %% [markdown]
# # New Section

# %%
type(extract)
# Out:
# str

# %%
import re
r1 = re.search(r"^[FA]...",extract)
print(r1)
# Out:
# None

# %%
x = re.split("\s", extract)
for i in range(len(x)):
  if x[i]=="No:":
    pj=x[i+1]
print(f'Invoice {pj}')
# Out:
# Invoice FACDS42100004180
