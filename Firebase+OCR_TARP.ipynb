# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 30 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 1s (4,643 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### **NEW TRY**

# %% [markdown]
# **# With Preprocessing**

# %% [markdown]
# ###Pdf to Jpg

# %%
# !pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 4.4MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61085 sha256=53024f2ad66a29e6d5b01b1a7bb3d6a7417c5c73a4287cfe2248201caaf29785
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
# importing required modules
import PyPDF2

# creating a pdf file object
pdfFileObj = open('invoice1.pdf', 'rb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-9f478ee6c954> in <module>()
#       3
#       4 # creating a pdf file object
# ----> 5 pdfFileObj = open('invoice1.pdf', 'rb')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'invoice1.pdf'

# %%
# creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)

# %%
# printing number of pages in pdf file
print(pdfReader.numPages)
# Out:
# 1

# %%
# creating a page object
pageObj = pdfReader.getPage(0)

# %%
# extracting text from page
print(pageObj.extractText())

# %%
# closing the pdf file object
pdfFileObj.close()

# %%
import cv2 
import pytesseract

img = cv2.imread('Invoice.png')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
extract=pytesseract.image_to_string(img, config=custom_config)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a5010a68e770> in <module>()
#       3
#       4 img = cv2.imread('Invoice.png')
# ----> 5 cv2_imshow(img)
#       6 # Adding custom options
#       7 custom_config = r'--oem 3 --psm 6'
#
# /usr/local/lib/python3.7/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
extract
# Out:
# "I\n8) . ee, a\n\nSold By: Tech-Connect Retail Private Limited , : Invoice Number # FAAAAB2006063222 |\nShip-from Address: NO. 42/1 & 43, KACHERAKANAHALLI VILLAGE,, JADIGENAHALLI HOBLI, HOSKOTE TALUK,, Bengaluru, Neneeeenn ene nnen ne nee enn ennennn tenner nn nennnnn ned\nKarnataka, INDIA - 560067, IN-KA\nGSTIN - 29AAICA4872D1ZK\nOrder ID: 0D117301766129235000 Bil| To Ship To\nOrder Date: 12-12-2019 Guru Raghavendran Guru Raghavendran\n\n. Room no 320, men's hostel c Room no 320, men's hostel c *Keep this invoice and\nInvoice Date: 12-12-2019 blockVit Chennai ,vandalur- blockVit Chennai ,vandalur- manufacturer box for\nPAN: AAICA4872D kelambakkam road, Near krisp it kelambakkam road, Near krisp it warranty purposes.\n\n. park. park.\nGIN: U52100D1.2010PTC202600 = Chennai 600127 Tamil Nadu Chennai 600127 Tamil Nadu\n\nPhone: xxxxxxxXxxx Phone: xxxxxxxXxxx\nTotal items: 1\nProduct Title Qty Gross Discount = Taxable IGSTZ% = Total %\nAmount = Value =\n\x0c"

# %%
type(extract)
# Out:
# str

# %%
import re
r1 = re.search(r"^[FA]...",extract)
print(r1)
# Out:
# None

# %%
x = re.split("\s", extract)
for i in range(len(x)):
  if x[i]=="No:":
    pj=x[i+1]
print(f'Invoice {pj}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-44a7ad4fed01> in <module>()
#       3   if x[i]=="No:":
#       4     pj=x[i+1]
# ----> 5 print(f'Invoice {pj}')
#
# NameError: name 'pj' is not defined

# %%
# !pip install pytesseract

# %%
# !pip install opencv-python

# %%
import cv2
import pytesseract

img = cv2.imread('Invoice2.PNG')
cv2_imshow(img)
# Adding custom options
custom_config = r'--oem 3 --psm 6'
extract=pytesseract.image_to_string(img, config=custom_config)
# Out:
# <PIL.Image.Image image mode=RGB size=1391x477 at 0x7FC0F64C8790>

# %%
extract
# Out:
# 'Tax Invoice Order Id: OD119306027932627000 _Invoice No: FACDS42100004180 GSTIN: 07BKJPG6024L1Z1\nOrder Date: 31-07-2020, 07:47 PM Invoice Date: 31-07-2020, 07:48 PM PAN: BKJPG6024L\nSold By Shipping ADDRESS Billing Address\n‘Supplies World, Pritam , Pritam B1/311, Tower-9, Silver City-2,\nD-14,U.G.F,D.D.A-LS.C, Plot No. 2,4&20-Mor Land, B1/311, Tower-9, Silver City-2, PL2,\nNew Rajinder Nagar, New Delhi, Pi-2, Opposite to Wipro Office,\nDELHI - 110060 Opposite to Wipro Office, Greater Noida - 201308, IN-UP\nGreater Noida - 201308, IN-UP\nGross Taxable\nProduct Description Qty Amount Discount Ye IGsTt Total\nPhilips SHE4305BK/00 Wired Headset Black | . -\nPhilips SHE4305BK/00 Headset w HSN: 85183000 | IGST: 18% 1 589.00 -0.00 499.15, 89.85 589.00\nShipping Charge 1 0.00 0 0.00 0.00 0.00\nTOTAL PRICE: 589.00\nTOTALQTY: 1 All values are in INR\nSeller Registered Address: Supplies World,\nD-14, UGF, DDALSC, , 2,4,20 Mor Land, New Rajinder Nagar, NEW DELHI - 110060.\nDeclaration\n‘The go
# ...

# %%
type(extract)
# Out:
# str

# %%
import re
r1 = re.search(r"^[FA]...",extract)
print(r1)
# Out:
# None

# %%
x = re.split("\s", extract)
for i in range(len(x)):
  if x[i]=="No:":
    pj=x[i+1]
print(f'Invoice {pj}')
# Out:
# Invoice FACDS42100004180

# %%
# !pip install python-firebase
# Out:
# Processing /root/.cache/pip/wheels/ba/40/ca/e41a25d7abb787092e837cb0f91f33b04b1a8fd9d17c2d33a6/python_firebase-1.2-cp37-none-any.whl
# ...

# %%
from firebase import firebase

FBConn = firebase.FirebaseApplication("https://invoicenumberreader-default-rtdb.firebaseio.com/", None)
data_to_upload = {'Invoice' : pj}
result = FBConn.post('/invoicenumberreader-default-rtdb/InvoiceReceived',data_to_upload)
# Out:
#   File "/usr/local/lib/python3.7/dist-packages/firebase/__init__.py", line 3
#     from .async import process_pool
#               ^
# SyntaxError: invalid syntax

# %%
# !pip install pyrebase

# %%
import pyrebase

firebaseConfig={"apiKey": "AIzaSyB7srEGIMlPjEUxyOXU0_ieounvhrxWFxg",
    "authDomain": "tarpproj-d0b73.firebaseapp.com",
    "databaseURL": "https://tarpproj-d0b73-default-rtdb.firebaseio.com",
    "projectId": "tarpproj-d0b73",
    "storageBucket": "tarpproj-d0b73.appspot.com",
    "messagingSenderId": "476300670840",
    "appId": "1:476300670840:web:621c06ba12208d04f83a8d",
    "measurementId": "G-EPGZY14PDD"}

firebase=pyrebase.initialize_app(firebaseConfig)
db=firebase.database()
#data={"Invoice_ID":pj}
#print(db.push(data))

data={"Name":"Pritam", "Location":["Noida", "IN-UP"], "Invoice_ID_From PDF":pj, "Invoice _ID From_Camera":pj}
db.child("Order 1").set(data)
data={"Name":"Pritam", "Location":["Noida", "IN-UP"], "Invoice_ID_From PDF":"FACDS42100034170", "Invoice _ID From_Camera":"FACDS42100034170"}
db.child("Order 2").set(data)
data={"Name":"Pritam", "Location":["Noida", "IN-UP"], "Invoice_ID_From PDF":"FACDS42100024167", "Invoice _ID From_Camera":"FACDS42100024167"}
db.child("Order 3").set(data)
data={"Name":"Pritam", "Location":["Noida", "IN-UP"], "Invoice_ID_From PDF":"FACDS42100014187", "Invoice _ID From_Camera":"FACDS42100014187"}
db.child("Order 4").set(data)
# Out:
# {'Invoice _ID From_Camera': 'FACDS42100014187',
#  'Invoice_ID_From PDF': 'FACDS42100014187',
#  'Location': ['Noida', 'IN-UP'],
#  'Name': 'Pritam'}

# %%
order1=db.child("Order 1").get()
ordt=order1.val()
if (ordt['Invoice _ID From_Camera']==ordt['Invoice_ID_From PDF']):
  print("Equal")
else:
  print("Not Equal")
# Out:
# Equal
